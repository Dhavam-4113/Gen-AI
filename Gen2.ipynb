# %%
# !pip install -q transformers torch accelerate sentencepiece

from transformers import pipeline
import torch

device = 0 if torch.cuda.is_available() else -1

print("="*60)
print("FOUNDATION MODELS DEMO")
print("="*60)

# ----------------------------
# SENTIMENT ANALYSIS
# ----------------------------

print("\nLoading Sentiment Analysis Model...")

sentiment = pipeline(
    "sentiment-analysis",
    model="distilbert-base-uncased-finetuned-sst-2-english",
    device=device
)

text = input("\nEnter a sentence:\n")

result = sentiment(text)

print("\nSentiment Analysis")
print("-"*40)
print("Sentence   :", text)
print("Label      :", result[0]["label"])
print("Confidence :", round(result[0]["score"],4))

# ----------------------------
# DOCUMENT CLASSIFICATION
# ----------------------------

print("\nLoading Document Classification Model...")

classifier = pipeline(
    "zero-shot-classification",
    model="facebook/bart-large-mnli",
    device=device
)

document = input("\nEnter a document:\n")

labels = [
    "Technology",
    "Sports",
    "Politics",
    "Entertainment",
    "Education",
    "Healthcare"
]

result = classifier(
    document,
    candidate_labels=labels
)

print("\nDocument Classification")
print("-"*40)

print("Predicted Category :", result["labels"][0])
print("Confidence Score   :", round(result["scores"][0],4))
# Out:
# ============================================================
# FOUNDATION MODELS DEMO
# ============================================================
#
# Loading Sentiment Analysis Model...
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B /  268MB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/104 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Enter a sentence:
# The Generative AI workshop was extremely informative and useful.
#
# Sentiment Analysis
# ----------------------------------------
# Sentence   : The Generative AI workshop was extremely informative and useful.
# Label      : POSITIVE
# Confidence : 0.9995
#
# Loading Document Classification Model...
# config.json:   0%|          | 0.00/1.15k [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B / 1.63GB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/515 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Enter a document:
# Artificial Intelligence and Machine Learning are transforming industries through automation and intelligent decision-making.
#
# Document Classification
# ----------------------------------------
# Predicted Category : Technology
# Confidence Score   : 0.9582
